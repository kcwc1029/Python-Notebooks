# %% [markdown]
# 函數是一個可以重複使用的程式碼區塊。主要目的是將一段特定的功能打包起來，
# 當你需要執行這個功能時，只要呼叫這個函數就行了。
#
# 使用函數有以下幾個主要優點：
# ![](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260420_1776670059.png)

# %% [markdown]
# ## 定義&呼叫函數

# %%
# 定義函數
def my_function():
    # 這是函數內部的程式碼
    print("這是一個簡單的函數。")

# 呼叫函數
my_function()
# Out:
# 這是一個簡單的函數。

# %% [markdown]
# ## 參數（Parameters）
# 參數就像是函數的輸入。你可以在呼叫函數時，傳遞資料給它，讓函數可以根據這些資料執行不同的動作。

# %%
### 範例單一參數
def greeting(name):
    print("嗨，", name, "早安！")

greeting("Nelson")
# Out:
# 嗨， Nelson 早安！

# %%
### 範例：多個參數
def subtract(x1, x2):
    result = x1 + x2
    print(result)

subtract(7, 3)
# Out:
# 10

# %%
### Keyword Arguments

# 使用關鍵字參數，順序可以不固定
def interest(interest_type, subject):
    print("主詞是:", subject)
    print("興趣是:", interest_type)

interest(subject="程式設計", interest_type="Python")

# %%
### 範例：預設參數

# 如果呼叫時沒給 msg，它就會自動帶入 "早安"
def greet_with_default(name, msg="早安"):
    print("嗨，", name, msg, "！")

greet_with_default("Nelson") # 情況 1：不提供第二個參數，使用預設值
greet_with_default("Nelson", "晚安") # 情況 2：提供第二個參數，覆蓋預設值
# Out:
# 嗨， Nelson 早安 ！
# 嗨， Nelson 晚安 ！

# %%
### 函數參數是串列

# Python也可以將list作為參數傳遞給函數。讓函數可以處理一組資料，而不是單一的數值。
def product_msg(customers):
    for customer in customers: # 這裡的 customers 是一個串列
        msg = 'str2' + customer + 'str2'
        print(msg)

customers = ['Damon', 'Peter', 'Mary']
product_msg(customers)
# Out:
# str2Damonstr2
# str2Peterstr2
# str2Marystr2

# %% [markdown]
# ## 傳遞任意數量的參數： *args 與 **kwargs
# ### *args
# 使用 * 加上一個參數名（通常用 *args），可以讓函數接收任意數量的位置參數。這些參數會被打包成一個元組（tuple）。

# %%
def make_icecream(*args):
    print("冰淇淋的配料：")
    for item in args:
        print(item)

make_icecream("草莓醬", "OREO餅乾", "巧克力碎片")
# Out:
# 冰淇淋的配料：
# 草莓醬
# OREO餅乾
# 巧克力碎片

# %% [markdown]
# ### **kwargs
# 使用 ** 加上一個參數名（通常用 **kwargs），可以讓函數接收任意數量的關鍵字參數。這些參數會被打包成一個字典（dictionary）。

# %%
def build_dict(**kwargs):
    print(kwargs['name'])

build_dict(name='James', Age='32', City='Cleveland', State='Ohio')
# Out:
# James

# %%
### 合併寫法：*args 與 **kwargs
def build_dict(*args, **kwargs):
    print(args)
    print(kwargs)
    return kwargs

player_dict = build_dict('James', Age='32', City='Cleveland', State='Ohio')
print(player_dict)
# Out:
# ('James',)
# {'Age': '32', 'City': 'Cleveland', 'State': 'Ohio'}
# {'Age': '32', 'City': 'Cleveland', 'State': 'Ohio'}

# %% [markdown]
# ## 練習：參數相關練習

# %% [markdown]
# ### Problem. 超市購物車總金額計算
# 超市的自助結帳機需要快速計算顧客購物車裡所有商品的總花費，這個函數需要能接收一整串的商品價格清單。
# * 函數名稱：calculate_total
# * 輸入變數：prices (包含多個商品價格的串列 list)
# * 輸出：回傳所有商品價格的加總金額 (整數)。
# <!--
# ```python=
# def calculate_total(prices):
#     total = 0
#     for price in prices:
#         total += price
#     return total
#
# # 測試呼叫
# cart = [35, 120, 89, 200]
# print(calculate_total(cart))
# ```
# -->

# %%
def calculate_total(cost):
  # ...

cost = [10,15,20,25,30]
calculate_total(cost)
cost = [11,12,13,14,15]
calculate_total(cost)
# Out:
#   File "/tmp/ipykernel_3986/1118995032.py", line 4
#     cost = [10,15,20,25,30]
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ### Problem. 電影票訂購確認訊息
# 影城售票系統在顧客完成線上訂票後，需要產生一段確認文字。為了避免系統將時間和座位帶錯位置，我們在呼叫函數時會明確使用「關鍵字參數」來傳遞資料。
# * 函數名稱：book_ticket
# * 輸入變數：
#     * movie_name (電影名稱，字串)
#     * time (場次時間，字串)
#     * seat (座位號碼，字串)
# * 輸出：回傳一段完整的字串，格式為：「您已成功訂購 [電影名稱]，場次 [時間]，座位為 [座位號碼]。」
# <!--
# ```python=
# def book_ticket(movie_name, time, seat):
#     return f"您已成功訂購 {movie_name}，場次 {time}，座位為 {seat}。"
#
# # 測試呼叫 (使用關鍵字參數，順序可任意調換)
# msg = book_ticket(seat="H-12", movie_name="星際效應", time="19:30")
# print(msg)
# ```
# -->

# %%
# 創造函數
def book_ticket(movie_name, time, seat):
  # ...

# 使用他
book_ticket("0409", "晚上8點", "16-4")

# %% [markdown]
# ### Problem. 每日記帳無上限加總
# 有時候我們一天會買很多零碎的東西（例如：買咖啡、買文具、繳水費）。記帳App需要一個功能，讓使用者可以一次輸入當天「任意數量」的花費金額，並計算出今天的總支出。
# * 函數名稱：daily_expenses
# * 輸入變數：expenses (任意數量的花費金額，整數)
# * 輸出：回傳當日的總花費金額 (整數)。若沒有傳遞任何數值，則回傳0
# <!--
# ```python=
# def daily_expenses(*expenses):
#     total_cost = 0
#     for expense in expenses:
#         total_cost += expense
#     return total_cost
#
# # 測試呼叫
# print(daily_expenses(55, 120, 30)) # 買了三樣東西
# print(daily_expenses())            # 今天沒花錢
# ```
# -->

# %% [markdown]
# ## 回傳值
# 要使用 return 關鍵字，函數可以將計算結果或資料回傳給呼叫它的地方。

# %%
### 範例：無回傳值
def greeting(name):
	print("嗨，" + name + "早安！")

result = greeting("Helena")
print(result)

# %%
### 範例：單一回傳值
def greeting(name):
    return "嗨，" + name + "早安！"

result = greeting("Helena")
print(result)

# %%
### 多個回傳值
# Python 的函數可以同時回傳多個值，這些值會被打包成一個元組（tuple）
def multifunc(x1, x2):
    addresult = x1 + x2
    subresult = x1 - x2
    return addresult, subresult

# 呼叫函數並接收回傳的多個值
add, sub = multifunc(10, 2)
print("加法結果：", add)
print("減法結果：", sub)

# %% [markdown]
# ## 練習：回傳值相關練習

# %% [markdown]
# ### Problem. 台北市 YouBike 2.0 騎乘費用計算
# 台北市 YouBike 2.0 目前的收費標準為：前 30 分鐘免費；超過 30 分鐘後，4 小時內每 30 分鐘 10 元（超過 30 分鐘的部分，未滿 30 分鐘以 30 分鐘計算）。請設計一個函數來計算預估費用。
# * 函數名稱：calculate_youbike_fee
# * 輸入變數：minutes (騎乘總分鐘數，整數)
# * 輸出：回傳計算後的費用 (整數)
# <!--
# ```python=
# import math
#
# def calculate_youbike_fee(minutes):
#     if minutes <= 30:
#         return 0
#     else:
#         # 扣除免費的30分鐘後，計算需要收費的時間
#         chargeable_minutes = minutes - 30
#         # math.ceil 可以無條件進位，用來計算收費區間的數量
#         intervals = math.ceil(chargeable_minutes / 30)
#         fee = intervals * 10
#         return fee
#
# # 測試呼叫
# result = calculate_youbike_fee(45)
# print("騎乘45分鐘的費用為：", result, "元")
# ```
# -->

# %% [markdown]
# ### Problem. 台灣銀行外幣兌換估算
# 出國旅遊前需要換匯，假設目前台灣銀行牌告匯率中，1 台幣大約可以兌換 4.71 日圓 (JPY) 或是 0.031 美元 (USD)。請設計一個函數，讓使用者輸入台幣預算後，同時得知可以換到多少日圓與美元。
# * 函數名稱：exchange_currency
# * 輸入變數：twd_amount (台幣金額，整數)
# * 輸出：回傳兩個值，分別為日圓金額與美元金額 (浮點數，請使用 round 函數四捨五入到小數點後兩位)
# <!--
# ```python=
# def exchange_currency(twd_amount):
#     jpy_rate = 4.71
#     usd_rate = 0.031
#
#     jpy_amount = round(twd_amount * jpy_rate, 2)
#     usd_amount = round(twd_amount * usd_rate, 2)
#
#     return jpy_amount, usd_amount
#
# # 測試呼叫並接收多個回傳值
# jpy, usd = exchange_currency(10000)
# print("一萬台幣約可兌換：", jpy, "日圓")
# print("一萬台幣約可兌換：", usd, "美元")
# ```
# -->

# %% [markdown]
# ### Problem. 台灣高鐵到站廣播系統
# 高鐵列車即將抵達特定車站時，車廂內會播放標準的中文語音廣播。這是一個單純執行印出動作的系統，不需要回傳任何計算結果。
# * 函數名稱：announce_arrival
# * 輸入變數：station_name (高鐵站名，字串)
# * 輸出：無回傳值 (None)。函數內需直接印出字串：「各位旅客您好，列車即將抵達 [station_name] 站。」
# <!--
# ```python=
# def announce_arrival(station_name):
#     print("各位旅客您好，列車即將抵達" + station_name + "站。")
#
# # 測試呼叫
# result = announce_arrival("台南")
# print("函數的回傳值為：", result) # 這裡會印出 None，讓學生理解無回傳值的概念
# ```
# -->

# %% [markdown]
# ### Problem. 中華郵政國內包裹資費計算
# 到郵局寄送國內包裹時，資費是依照重量計算的。不逾 5 公斤收費 70 元；逾 5 公斤不逾 10 公斤收費 90 元；逾 10 公斤不逾 15 公斤收費 110 元；逾 15 公斤不逾 20 公斤收費 135 元。請設計一個函數來自動判定郵資。
# * 函數名稱：calculate_postage
# * 輸入變數：weight_kg (包裹重量，公斤，浮點數)
# * 輸出：回傳應收郵資 (整數)
# <!--
# ```python=
# def calculate_postage(weight_kg):
#     if weight_kg <= 5:
#         return 70
#     elif weight_kg <= 10:
#         return 90
#     elif weight_kg <= 15:
#         return 110
#     else:
#         return 135
#
# # 測試呼叫
# postage_fee = calculate_postage(7.5)
# print("7.5公斤的包裹郵資為：", postage_fee, "元")
# ```
# -->

# %% [markdown]
# ### Problem. 台電住宅用電費估算
# 台灣電力公司的電價會區分「夏月」與「非夏月」。假設我們只計算單一級距（每月用電度數在 121 到 330 度之間），夏月每度電為 2.45 元，非夏月每度電為 2.16 元。請設計一個函數，根據用電度數同時回傳夏月與非夏月的預估電費。
# * 函數名稱：estimate_electricity
# * 輸入變數：kwh (用電度數，整數)
# * 輸出：回傳兩個值，分別為夏月電費與非夏月電費 (整數，可直接使用 int() 轉換去除小數點)
# <!--
# ```python=
# def estimate_electricity(kwh):
#     summer_rate = 2.45
#     non_summer_rate = 2.16
#
#     summer_fee = int(kwh * summer_rate)
#     non_summer_fee = int(kwh * non_summer_rate)
#
#     return summer_fee, non_summer_fee
#
# # 測試呼叫並接收多個回傳值
# summer, non_summer = estimate_electricity(250)
# print("用電250度，夏月電費約為：", summer, "元")
# print("用電250度，非夏月電費約為：", non_summer, "元")
# ```
# -->

# %% [markdown]
# ## Docstring
# Docstring 是一種良好的程式設計習慣。它位於函數定義的第一行，以三個引號 `"""` 包裹，用來清楚描述函數的用途與功能。
# -   自我說明：程式本身就能解釋功能，減少額外註解的需求。
# -   協作便利：其他人閱讀程式時，可以快速理解函數的目的。
# -   維護效率：在程式更新或擴充時，Docstring 提供清晰的功能定位。

# %%
def calculate_area(width, height):
    """
    計算矩形的面積。

    參數:
        width (float): 矩形的寬度。
        height (float): 矩形的高度。

    回傳:
        float: 矩形的面積。
    """
    return width * height

# %% [markdown]
# ## 補充：函數是物件
# 函數本身就是一種物件，這意味著你可以將函數賦予給變數，或者作為參數傳遞給另一個函數。

# %%
def add(x, y):
    return x + y

def mul(x, y):
    return x * y

def running(func, arg1, arg2):
    return func(arg1, arg2)

result = running(add, 5, 10)
print(result)

# %% [markdown]
# ## 補充：函數可以做為回傳
# 一個函數也可以回傳另一個函數，這在進階程式設計中很常用。

# %%
def create_multiplier(number):
    def multiplier(num):
        return number * num
    return multiplier

double_function = create_multiplier(2)
triple_function = create_multiplier(3)

print("兩倍數字：", double_function(5))
print("三倍數字：", triple_function(5))

# %% [markdown]
# ## 練習

# %% [markdown]
# ### Problem 1. 網購免運費判斷
# 網購平台規定：購物車滿 1000 元（含）即享免運費；若未滿 1000 元，則需加收 60 元的物流運費。請寫一個函數幫結帳系統算出顧客最終需要支付的金額。
#
# * 函數名稱：calculate_checkout
# * 輸入變數：amount (購物車總額，整數)
#
# 輸出：回傳加上運費（如果有的話）的最終結帳金額 (整數)。

# %% [markdown]
# ### Problem 2. 飲料店快速點餐系統
# 飲料店的 POS 系統需要記錄客人的飲料與冰塊甜度。因為大部分客人都是點「正常冰、正常糖」，請設計一個函數，使用「預設參數」，讓店員在客人沒特別指定時，可以少輸入一些字。
#
# * 函數名稱：order_drink
# * 輸入變數：drink_name (飲料名稱，字串)、ice (冰塊，字串，預設為 "正常冰")、sugar (甜度，字串，預設為 "正常糖")
#
# 輸出：回傳一段確認字串，格式為："您點的是[飲料名稱]，[冰塊]，[甜度]。"

# %% [markdown]
# ### Problem 3. 尋找班上最高分
# 老師想在期末考後，快速找出班上的最高分是幾分，以便決定是否要調整成績。請設計一個函數來找出串列中的最大值。（提示：可以使用 Python 內建函數或使用 for 迴圈逐一比較）
#
# * 函數名稱：find_highest
# * 輸入變數：scores (包含多個成績的串列 list)
#
# 輸出：回傳串列中的最高分數 (整數)。

# %% [markdown]
# ### Problem 4. 網站密碼強度檢查員
# 網站註冊系統需要檢查使用者設定的密碼長度，為了安全起見，如果密碼長度少於 8 個字元，系統要拒絕註冊。
# * 函數名稱：check_password
# * 輸入變數：password (使用者輸入的密碼，字串)
#
# 輸出：若密碼長度大於或等於 8，回傳 True；否則回傳 False (布林值)。

# %% [markdown]
# ### Problem 5. 餐廳分帳計算機 (多個回傳值)
# 一群朋友去吃熱炒，結帳時需要把總金額平分。但結帳時只能付整數（小數點無條件捨去），剩下的零頭由當天請客的壽星吸收。請設計一個函數計算每個人要付多少錢，以及壽星要幫忙出的零頭。
#
# * 函數名稱：split_bill
# * 輸入變數：total_amount (總金額，整數)、people (人數，整數)
# * 輸出：同時回傳兩個值：每個人平均應付的金額 (整數)、剩下的零頭 (整數)。
# * 提示：可以使用整數除法 // 與 取餘數 %。

# %% [markdown]
# ### Problem 6. 及格人數統計器
# 助教拿到了一份平時測驗的成績單，他需要統計這次考試中，成績及格（大於或等於 60 分）的同學總共有幾位。
#
# * 函數名稱：count_pass
# * 輸入變數：scores (包含多個成績的串列 list)
#
# 輸出：回傳及格的「總人數」 (整數)。

# %% [markdown]
# ### Problem 7. 停車費計算機
# 停車場的計費規則如下：不論停多久，基本費用就是 50 元；但如果停車時間超過 2 小時（120 分鐘），超過的部分每分鐘加收 1 元。請寫一個函數幫繳費機計算費用。
#
# * 函數名稱：parking_fee
# * 輸入變數：minutes (總停留分鐘數，整數)
# 輸出：回傳總停車費用 (整數)。

# %% [markdown]
# ## Lambda：匿名函數
# 顧名思義就是沒有名稱的函數。它們通常只用於一個簡單的、一次性的任務。
# ```py
# lambda 參數: 運算式
# # 參數：是輸入，可以有多個，用逗號分隔。
# # 運算式：是函數體，只能有一個運算式，且其結果會被自動回傳，不用 return
# ```

# %%
### 範例：基本運算
# 平方Lambda 函數
square = lambda x: x ** 2
print(square(10))

# 定義一個將兩個數相加的 Lambda 函數
add = lambda x, y: x + y
print(add(5, 3))  # 輸出: 8

# 定義一個將數字乘以 3 的 Lambda 函數
multiply_by_three = lambda x: x * 3
print(multiply_by_three(4))  # 輸出: 12

# %%
### 範例：條件運算
# 返回兩個數中較大的值
max_num = lambda x, y: x if x > y else y
print(max_num(10, 15))  # 輸出: 18
print(max_num(20, 5))   # 輸出: 20

# %%
### 範例：結合多個參數和運算
# 計算 (x + y) * z 的 Lambda 函數
complex_calc = lambda x, y, z: (x + y) * z
print(complex_calc(2, 3, 4))  # 輸出: 20

# %%
### 範例：列表依照元素長度排序
# 使用 Lambda 作為 sorted() 的 key 函數，按特定條件排序。
words = ["apple", "banana", "cherry"]
sorted_words = sorted(words, key=lambda x: len(x))
print(sorted_words)  # 輸出: ['apple', 'cherry', 'banana']

# %%
### 範例：列表忽略大小寫排序
words = ["Banana", "apple", "Cherry", "date"]

sorted_words = sorted(words, key=lambda x: x.lower())
print(sorted_words)
# 輸出: ['apple', 'Banana', 'Cherry', 'date']

# %%
### 範例：列表依數字的絕對值排序
# 範例：依數字的絕對值排序
numbers = [-10, 5, -3, 8, -1]
sorted_numbers = sorted(numbers, key=lambda x: abs(x))
print(sorted_numbers)
# 輸出: [-1, -3, 5, 8, -10]

# %% [markdown]
# ## 補充：高階函數
# 高階函數指的是能夠 接收其他函數作為參數，或 將函數作為回傳值 的函數。這種設計讓程式更具彈性與抽象性，能以更簡潔的方式表達複雜的邏輯。
# > 因此經常搭配lambda
#
# -   `filter()`：用來篩選符合條件的元素。
# -   `map()`：將函數套用到每個元素，產生新序列。
# -   `reduce()`：累積計算序列中的元素，常用於加總或合併。
#
# ![upgit_20260420_1776670779.png|329x184](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260420_1776670779.png)

# %% [markdown]
# ### filter()：過濾串列中的元素，只保留符合特定條件的
# ```py
# filter(函數, iterable)
# # 函數：一個判斷條件的函數，回傳 True 或 False。
# # iterable：可迭代的物件，如串列、元組等。
# ```

# %%
# 使用 filter() 篩選健康數據
# filter() 用於篩選出符合特定條件的健康數據，例如過濾出心率超過正常範圍（假設正常範圍為 60-100 bpm）的數據。

# 模擬高齡者心率數據列表（單位：beats per minute）
heart_rates = [55, 72, 85, 110, 65, 120, 90]

# 使用 filter 篩選出異常心率（> 100 或 < 60）
abnormal_rates = list(filter(lambda x: x > 100 or x < 60, heart_rates))
print(abnormal_rates)  # 輸出: [55, 110, 120]

# %% [markdown]
# ### map()：對串列中的每個元素執行相同的操作，並回傳新的結果
# ```py
# map(函數, iterable)
# # 函數：一個處理每個元素的函數。
# ```

# %%
# 使用 map() 轉換健康指標
# map() 用於對每個健康數據執行相同的操作，例如將攝氏溫度轉換為華氏溫度，模擬環境感測器數據處理。

# 模擬高齡者居住環境的攝氏溫度列表
celsius_temps = [22, 25, 18, 30]

# 使用 map 將攝氏轉換為華氏 (°F = °C * 9/5 + 32)
fahrenheit_temps = list(map(lambda x: x * 9/5 + 32, celsius_temps))
print(fahrenheit_temps)  # 輸出: [71.6, 77.0, 64.4, 86.0]

# %% [markdown]
# ### reduce()：對串列中的元素進行累積運算，將所有元素歸納成一個單一值。
# ```py
# from functools import reduce
#
# reduce(函數, iterable)
# # 函數：必須有兩個參數，分別是累積值和下一個元素。
# ```

# %%
from functools import reduce

# 模擬一天內多次測量的血氧濃度數據
blood_oxygen = [95, 97, 94, 96, 98]

# 使用 reduce 計算總和
total_oxygen = reduce(lambda x, y: x + y, blood_oxygen)
average_oxygen = total_oxygen / len(blood_oxygen)
print(f"平均血氧濃度: {average_oxygen}")  # 輸出: 平均血氧濃度: 96.0

# %% [markdown]
# ## 變數作用域 (Scope)
# Scope決定了該變數在程式中可被存取的範圍。理解作用域能避免命名衝突，並提升程式的可讀性與維護性。
#
# - 區域變數 (Local Variables)：在函數內部定義，只能在該函數內使用。當函數執行結束後，區域變數也會消失。
# - 全域變數 (Global Variables)：在所有函數之外定義，可在程式的任何地方存取。若要在函數內修改全域變數，必須使用 global 關鍵字，明確告訴程式你要操作的是全域範圍的變數。

# %%
global_msg = "Global Variable"

def printMsg():
    # 可以在函數內部讀取全域變數
    print("函數內可以讀取:", global_msg)

print("主程式可以讀取:", global_msg)
printMsg()

# %% [markdown]
# ## pass
# 在 Python 中，pass 是一個空語句，什麼也不做。
# 只作為佔位符，常用於：
# - 尚未完成的程式結構：先定義函數或類別框架，避免因為內容空白而報錯。
# - 保持語法完整：在需要程式碼但暫時不打算撰寫的地方使用。
#
# ```py
# def calculate_total_price(items):
#     pass  # 未來會實現計算總價的邏輯，但現在只是佔位
# ```

# %%
# 空的條件語句
age = 20
if age >= 18:
    pass  # 未來會加入成年後的處理邏輯
else:
    print("未成年")

# %%
# 空的迴圈
for i in range(5):
    pass  # 未來會加入迴圈內的處理邏輯

# %%
# 空的類定義
class MyClass:
    pass  # 未來會加入類的屬性和方法

# %% [markdown]
# ## 專案
# * [猜數字遊戲](./函數_projects/猜數字遊戲.py)
# * [Blackjack(CLI版)](./函數_projects/Blackjack(CLI版).ipynb)
# * [點餐系統](./函數_projects/restaurant_order_system.py)
# * [AI 聊天機器人(規則版)](./函數_projects/rule_based_ai_chatbot.py)
# * [簡易 ATM 系統](./函數_projects/simple_atm_system.py)

# %% [markdown]
# ## Zerojude練習題目
#
# * [Zerojudee練習題目](./函數_practice/Zerojudge題目.txt)
