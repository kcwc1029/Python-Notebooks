# %%
print(123)
# Out:
# 123

# %% [markdown]
# ## Problem. 建立你的第一個資料置物櫃
# 想像你今天早上買了一份 65 元的早餐。現在，我們要請 Python 幫你準備一個專屬的「置物櫃」來記住這個花費，然後把它拿出來給我們看！
#
# 請跟著以下步驟寫程式：
# * 命名置物櫃：我們把這個置物櫃取名為 `breakfast_cost`（意思是早餐花費）。
# * 放入資料：請用等號 `=`，把數字 `65` 放進 `breakfast_cost` 裡面。
# * 取出資料：請換到下一行，用 `print()` 指令，把 `breakfast_cost` 裡面的數字印出來。
#
# <!--
# 解答
# breakfast_cost = 65 # 建立 breakfast_cost 置物櫃，放入 65
# print(breakfast_cost) # 取出並印出置物櫃裡的資料
# -->

# %%
# Out:
# 65

# %% [markdown]
# ## Problem. 幫自己算算每個月的買菜錢
# 假設你每天去菜市場平均會花掉 300 元。我們現在要請 Python 幫忙算算看，如果連續買 30 天的菜，總共會花多少錢呢？
#
# 請跟著以下步驟寫程式：
# * 建立第一個置物櫃，叫做 `daily_cost`（每天花費），並把數字 `300` 放進去。
# * 建立第二個置物櫃，叫做 `days`（天數），並把數字 `30` 放進去。
# * 建立第三個置物櫃，叫做 `monthly_cost`（每月總花費）。請用 `daily_cost * days` 計算，並用 `=` 將結果存進去。
# * 用 `print()` 指令，把 `monthly_cost` 的計算結果印出來。
#
# <!--
# ```python=
# daily_cost = 300 # 每天花費
# days = 30 # 天數
# monthly_cost = daily_cost * days # 每月總花費 = 每天花費 * 天數
# print(monthly_cost) # 印出結果
# ```
# -->

# %%
daily_cost = 300
days = 30
monthly_cost = daily_cost * days
print(monthly_cost)
# Out:
# 9000

# %% [markdown]
# ## Problem. 幫忙算下午茶花費
# 下午茶時間到了，你要幫同事們買咖啡。一杯咖啡 55 元，總共要買 4 杯，請讓 Python 幫你算總價。
#
# 請跟著以下步驟寫：
# * 建立變數 `coffee_price`（咖啡單價），放進數字 `55`。
# * 建立變數 `cups`（杯數），放進數字 `4`。
# * 建立變數 `total_cost`（總花費），用 `coffee_price * cups` 計算，並用 `=` 將結果存進去。
# * 使用 `print()` 印出 `total_cost`。
#
# <!--
# ```python=
# coffee_price = 55
# cups = 4
# total_cost = coffee_price * cups
# print(total_cost)
# ```
# -->

# %%
coffee_price = 65
cups = 6
total_cost = coffee_price * cups
print(total_cost)
# Out:
# 390

# %% [markdown]
# ## Problem. 算算看正方形的面積
# 在 Python 中，次方運算使用兩個星號 `**`。現在我們要計算一個邊長為 `7` 的正方形面積。
#
# 請跟著以下步驟寫：
# * 建立變數 `side_length`（邊長），放進數字 `7`。
# * 建立變數 `area`（面積），用 `side_length ** 2` 計算，並用 `=` 將結果存進去。
# * 使用 `print()` 印出 `area`。
#
# <!--
# ```python=
# side_length = 7
# area = side_length ** 2
# print(area)
# ```
# -->

# %%
side_length = 7
area = side_length ** 2
print(area)
# Out:
# 49

# %% [markdown]
# ## Problem. 能買幾個完整的麵包
# 你身上有 100 元，便利商店的一個麵包賣 30 元。你想知道手上的錢最多可以買幾個完整的麵包（不含小數）。
#
# 請跟著以下步驟寫：
# * 建立變數 `my_money`（我的錢），放進數字 `100`。
# * 建立變數 `bread_price`（麵包價格），放進數字 `30`。
# * 建立變數 `max_breads`（最多能買的數量），使用整除符號 `//`，將 `my_money // bread_price` 的結果存進去。
# * 使用 `print()` 印出 `max_breads`。
#
# <!--
# ```python=
# my_money = 100
# bread_price = 30
# max_breads = my_money // bread_price
# print(max_breads)
# ```
# -->

# %%
# Out:
# 3

# %% [markdown]
# ## Problem. 買完麵包會找多少錢？
# 你身上有 100 元，便利商店的一個麵包賣 30 元。買完所有能買的完整麵包後，老闆應該找你多少零錢？
#
# 請跟著以下步驟寫：
# * 建立變數 `my_money`（我的錢），放進數字 `100`。
# * 建立變數 `bread_price`（麵包價格），放進數字 `30`。
# * 建立變數 `change`（找零），使用取餘數符號 `%`，將 `my_money % bread_price` 的結果存進去。
# * 使用 `print()` 印出 `change`。
#
# <!--
# ```python=
# my_money = 100
# bread_price = 30
# change = my_money % bread_price
# print(change)
# ```
# -->

# %%
my_money = 100
bread_price = 30
change = my_money % bread_price
print(change)
# Out:
# 10

# %% [markdown]
# ## Problem. 整除與取餘數的應用
# 假設你收集了 256 顆寶石，想把這些寶石裝進箱子裡。
#
# 請跟著以下步驟寫：
# * 建立變數 `total_gems`，儲存寶石總數 `256`。
# * 建立變數 `box_capacity`，儲存每個箱子最多能裝 `10` 顆寶石。
# * 建立變數 `full_boxes`（完整的箱子數），使用整除 `//`，計算需要多少個完整的箱子。
# * 建立變數 `remaining_gems`（剩餘寶石數），使用取餘數 `%`，計算裝完完整箱子後還剩幾顆。
# * 使用 `print()` 分別印出 `full_boxes` 和 `remaining_gems`。
#
# <!--
# ```python=
# total_gems = 256
# box_capacity = 10
#
# full_boxes = total_gems // box_capacity
# remaining_gems = total_gems % box_capacity
#
# print(full_boxes)
# print(remaining_gems)
# ```
# -->

# %% [markdown]
# ## Problem. 把秒數換算成分鐘與秒
# 你的手機顯示一首歌的長度是 `254` 秒，但你想知道這首歌到底是幾分幾秒。
#
# 請跟著以下步驟寫：
# * 建立變數 `total_seconds`（總秒數），放進數字 `254`。
# * 建立變數 `minutes`（分鐘數），用整除 `//` 計算 `total_seconds // 60`，存進去。
# * 建立變數 `seconds`（剩餘秒數），用取餘數 `%` 計算 `total_seconds % 60`，存進去。
# * 使用 `print()` 分別印出 `minutes` 和 `seconds`。
#
# <!--
# ```python=
# total_seconds = 254
# minutes = total_seconds // 60
# seconds = total_seconds % 60
# print(minutes)
# print(seconds)
# ```
# -->

# %% [markdown]
# ## Problem. 計算正方體的體積
# 一個正方體的邊長是 `5` 公分，請用次方運算 `**` 計算它的體積。
#
# 請跟著以下步驟寫：
# * 建立變數 `edge`（邊長），放進數字 `5`。
# * 建立變數 `volume`（體積），用 `edge ** 3` 計算，並用 `=` 將結果存進去。
# * 使用 `print()` 印出 `volume`。
#
# <!--
# ```python=
# edge = 5
# volume = edge ** 3
# print(volume)
# ```
# -->

# %% [markdown]
# ## Problem. 綜合挑戰：幫工讀生算年薪與年儲蓄
# 小明在打工，時薪是 `168` 元，每天工作 `8` 小時，每年工作 `250` 天。小明每個月的固定支出是 `8500` 元。請幫他計算一年下來能存多少錢？
#
# 請跟著以下步驟寫：
# * 建立變數 `hourly_salary`（時薪），放進數字 `168`。
# * 建立變數 `annual_salary`（年薪），用 `hourly_salary * 8 * 250` 計算，存進去。
# * 建立變數 `monthly_expense`（每月支出），放進數字 `8500`。
# * 建立變數 `annual_expense`（年支出），用 `monthly_expense * 12` 計算，存進去。
# * 建立變數 `annual_savings`（年儲蓄），用 `annual_salary - annual_expense` 計算，存進去。
# * 使用 `print()` 印出 `annual_savings`。
#
# <!--
# ```python=
# hourly_salary = 168
# annual_salary = hourly_salary * 8 * 250
# monthly_expense = 8500
# annual_expense = monthly_expense * 12
# annual_savings = annual_salary - annual_expense
# print(annual_savings)
# ```
# -->
