# %% [markdown]
# ### Problem. 秒數轉分鐘
#
# 已知：
# ```
# seconds = 150
# ```
# 請計算：
#
# - 幾分鐘
# - 剩下幾秒

# %% [markdown]
# ### Problem. 雞蛋盒問題
#
# 一盒可以裝 12 顆蛋。現在有 50 顆蛋。
#
# 請計算：
# * 可以裝滿幾盒
# * 剩下幾顆

# %% [markdown]
# ### Problem. 次方計算
#
# 一盒可以裝 12 顆蛋。現在有 50 顆蛋。
#
# 請計算：
# ```
# 3 的平方
# 5 的平方
# 2 的 5 次方
# ```

# %% [markdown]
# ### Problem. 面積與體積
#
# 已知正方形邊長：
# ```
# side = 4
# ```
# 請計算：
# - 面積
# - 體積(立方體)

# %% [markdown]
# ### Problem. 披薩切片
#
# 一個披薩有 8 片。5 個人平均分。
#
# 請計算：
# * 每人幾片
# * 剩下幾片
