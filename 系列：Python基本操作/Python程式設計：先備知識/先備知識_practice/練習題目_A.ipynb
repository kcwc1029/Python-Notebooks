# %% [markdown]
# ### Problem. 計算兩數相加
#
# 建立：
# ```
# a = 10
# b = 20
# ```
#
# 輸出兩數相加結果。

# %% [markdown]
# ### Problem. 飲料價格計算
#
# 一杯紅茶 35 元。今天買了 4 杯。
# - 請計算總金額。
# - 輸出兩數相加結果。

# %% [markdown]
# ### Problem. 計算長方形面積
#
# 已知：
# ```
# width = 10
# height = 5
# ```
# 請輸出長方形面積。

# %% [markdown]
# ### Problem. 計算 BMI
#
# 建立：
# ```
# height = 170
# weight = 60
# ```
#
# BMI 公式：體重 / (身高公尺 ** 2)
#
# > 提示：身高需要先轉公尺

# %% [markdown]
# ### Problem. 時薪計算
#
# 時薪 196 元。
#
# 一天工作 8 小時。一個月工作 22 天。
#
# 請計算月薪。

# %% [markdown]
# ### Problem. 超商購物平均
#
# 購買：
#
# - 飯糰 39 元
# - 奶茶 35 元
# - 茶葉蛋 13 元
#
# 請計算平均。
