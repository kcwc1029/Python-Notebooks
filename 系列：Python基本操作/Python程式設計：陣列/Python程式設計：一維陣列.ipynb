# %% [markdown]
# 陣列是 Python 中一種最常見的資料型態，可以儲存多個不同型態的元素，例如數字、字串、布林值等。

# %% [markdown]
# ## 定義串列
#
# ![upgit_20260421_1776782073.png](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260421_1776782073.png)

# %%
# 定義一個數字串列
james = [23, 19, 22, 31, 18]

# 定義一個字串串列
fruits = ['apple', 'banana', 'orange']

# 混合型態的串列
leits = [3.5, 6.0, 8.5, 'leits']

# 建立一個空串列，之後可以再加入元素
new_list = []

arr = [1, 2, 3]

# %% [markdown]
# ## 讀取串列元素
# 透過索引 (index) 來取得串列中的特定元素。索引從 0 開始。
# * x[0]：取得第一個元素
# * x[1]：取得第二個元素
# * x[-1]：取得最後一個元素

# %%
james = [23, 19, 22, 31, 18]



print(james[0]) # 取得第一個元素
print(james[2]) # 取得第三個元素
print(james[-1]) # 取得最後一個元素
# Out:
# 18

# %% [markdown]
# ### 更改串列元素的內容

# %%
cars = ['Honda', 'Toyota', 'Ford']
print(cars[1])
cars[1] = 'Nissan' # 將索引 1 的元素改成 'Nissan'
print(cars) # 輸出: ['Honda', 'Nissan', 'Ford']
# Out:
# Toyota
# ['Honda', 'Nissan', 'Ford']

# %% [markdown]
# ### Problem. 成績單索引查詢
# 請建立一個名為 `math_scores` 的串列，依序放入五位學生的數學分數：`88, 72, 95, 64, 81`。 接著，請分別執行以下操作並將結果印出：
# 1.  取出串列中的第一個分數（索引為 0）。
# 2.  取出串列中的第四個分數。
# 3.  使用負數索引取出串列中的最後一個分數。
#
# 輸出範例：
# ```
# 第一個分數是：88
# 第四個分數是：64
# 最後一個分數是：81
# ```
#
# <!--
# ```python=
# # 題目一解答
# math_scores = [88, 72, 95, 64, 81]
# print(f"第一個分數是：{math_scores[0]}")
# print(f"第四個分數是：{math_scores[3]}")
# print(f"最後一個分數是：{math_scores[-1]}")
# ```
# -->

# %%
math_scores = [88, 72, 95, 64, 81]

# %% [markdown]
# ## 串列切片

# %%
warriors = ['Curry', 'Durant', 'Iguodala', 'Bell', 'Thompson']

# 取得索引 0 到 3 (不包含) 的元素
print(warriors[0:3]) # 輸出: ['Curry', 'Durant', 'Iguodala']

# 取得索引 2 到最後的元素
print(warriors[2:]) # 輸出: ['Iguodala', 'Bell', 'Thompson']

# 取得所有元素
print(warriors[:]) # 輸出: ['Curry', 'Durant', 'Iguodala', 'Bell', 'Thompson']

# 從頭到尾，每隔一個元素取一個
print(warriors[::2]) # 輸出: ['Curry', 'Iguodala', 'Thompson']

# 反轉串列
print(warriors[::-1]) # 輸出: ['Thompson', 'Bell', 'Iguodala', 'Durant', 'Curry']
# Out:
# ['Curry', 'Durant', 'Iguodala']
# ['Iguodala', 'Bell', 'Thompson']
# ['Curry', 'Durant', 'Iguodala', 'Bell', 'Thompson']
# ['Curry', 'Iguodala', 'Thompson']
# ['Thompson', 'Bell', 'Iguodala', 'Durant', 'Curry']

# %% [markdown]
# ### Problem. 球隊名單切片練習
# 現有一個名為 `team_members` 的球員名單串列，內容為：`['Jordan', 'Pippen', 'Rodman', 'Kukoc', 'Kerr', 'Harper']`。 請撰寫程式完成以下切片操作：
# 1.  取得索引 1 到 4（不包含 4）的球員名單，並將結果存入變商 `sub_team`。
# 2.  取得從索引 3 開始到最後的所有球員。
# 3.  取得從開頭到索引 2（不包含 2）的球員。
# 4.  使用切片功能，**由後往前**反轉整個球員名單。
#
# ```
# 部分名單：['Pippen', 'Rodman', 'Kukoc']
# 後半段名單：['Kukoc', 'Kerr', 'Harper']
# 前半段名單：['Jordan', 'Pippen']
# 反轉後的名單：['Harper', 'Kerr', 'Kukoc', 'Rodman', 'Pippen', 'Jordan']
# ```
#
# <!--
# ```python=
# # 題目二解答
# team_members = ['Jordan', 'Pippen', 'Rodman', 'Kukoc', 'Kerr', 'Harper']
# sub_team = team_members[1:4]
# print(f"部分名單：{sub_team}")
# print(f"後半段名單：{team_members[3:]}")
# print(f"前半段名單：{team_members[:2]}")
# print(f"反轉後的名單：{team_members[::-1]}")
# ```
# -->

# %%
team_members = ['Jordan', 'Pippen', 'Rodman', 'Kukoc', 'Kerr', 'Harper']

print(team_members[1:4])
print(team_members[3:6])
print(team_members[0:2])
# Out:
# ['Pippen', 'Rodman', 'Kukoc']
# ['Kukoc', 'Kerr', 'Harper']
# ['Jordan', 'Pippen']

# %% [markdown]
# ## 串列統計函式
# Python 提供了一些內建函式，可以對串列進行統計。
# * max(x)：回傳串列中的最大值
# * min(x)：回傳串列中的最小值
# * sum(x)：回傳串列中所有元素的總和 (僅限數字串列)
# * len(x)：回傳串列中元素的數量

# %%
james = [23, 19, 22, 31, 18, 100, 200]

print(len(james))
print(max(james))
print(min(james))
print(sum(james))
print(sum(james) / len(james))
# Out:
# 7
# 200
# 18
# 413
# 59.0

# %%
print(f"最大值: {max(james)}") # 輸出: 31
print(f"最小值: {min(james)}") # 輸出: 18
print(f"總和: {sum(james)}") # 輸出: 113
print(f"元素數量: {len(james)}") # 輸出: 5

# %% [markdown]
# ### Problem. 尋找最差表現
# 撰寫一程式，讀取含括號之整數序列字串（如 [12, 8, 15]），利用 eval() 函式將其轉換為串列 scores。隨後運用 Python 內建函式檢索其最小值（Min）與算術總和（Sum）。
#
# * 輸入：[12, 8, 15, 6, 10]
# * 第一行輸出 min(scores)，
# * 第二行輸出 sum(scores)。

# %%
scores = [12, 8, 15, 6, 10]

# 輸出最小值
a = min(scores)
print(a)

# 輸出最大值
a = max(scores)
print(a)
# Out:
# 6
# 15

# %% [markdown]
# ## 增加串列元素
# -   `append(元素)`：固定加在串列的最後面。
# -   `insert(索引, 元素)`：可以插隊到指定的位置。
#
# ![upgit_20260421_1776782328.png](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260421_1776782328.png)

# %%
cars = ['Toyota', 'Ford', 'Tesla']
cars.append('Honda')
print(cars)
# Out:
# ['Toyota', 'Ford', 'Tesla', 'Honda']

# %%
cars = ['Toyota', 'Ford', 'Tesla']
cars.insert(1, 'BMW')
print(cars)
# Out:
# ['Toyota', 'BMW', 'Ford', 'Tesla']

# %% [markdown]
# ### Problem.美食清單的增員計畫
# 請建立一個名為 `foods` 的串列，初始內容包含：`'牛肉麵', '滷肉飯', '珍奶'`。
# 1.  最後一刻加入： 使用 `append()` 在串列末端加入 `'雞排'`。
# 2.  插隊推薦： 使用 `insert()` 在索引 `1` 的位置（也就是第二個位置）插入 `'小籠包'`。
# 3.  成果展示： 最後印出 `foods` 串列。
#
# 輸出內容：
# ```
# 最後的清單：['牛肉麵', '小籠包', '滷肉飯', '珍奶', '雞排']
# ```
#
# <!--
# ```python=
# foods = ['牛肉麵', '滷肉飯', '珍奶']
# foods.append('雞排')
# foods.insert(1, '小籠包')
# print(f"最後的清單：{foods}")
# ```
# -->

# %%
foods = ['牛肉麵', '滷肉飯', '珍奶']

# 第一個結果
foods.append("雞排")
print(foods)

# 第二個結果
foods.insert(1, "小籠包")
print(foods)

# 插一個香蕉煎餅
foods.insert(0, "香蕉煎餅")
print(foods)
# Out:
# ['牛肉麵', '滷肉飯', '珍奶', '雞排']
# ['牛肉麵', '小籠包', '滷肉飯', '珍奶', '雞排']
# ['香蕉煎餅', '牛肉麵', '小籠包', '滷肉飯', '珍奶', '雞排']

# %% [markdown]
# ## 刪除元素
# -   `pop(索引)`：「取出」。會把元素拿出來給你用（預設最後一個）。
# -   `remove(內容)`：「指名」。直接刪除第一個符合該名稱的元素。
# -   `del`：「切除」。直接從記憶體中刪除指定索引或一段範圍。
#
#
# ![upgit_20260421_1776782382.png|329x148](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260421_1776782382.png)

# %%
### pop用法
brands = ['Apple', 'Google', 'Meta', 'Amazon', 'Meta', 'Microsoft']
t = brands.pop() # 刪掉Microsoft
print(brands)
print(t)
# Out:
# ['Apple', 'Google', 'Meta', 'Amazon', 'Meta']
# Microsoft

# %%
### remove用法
brands = ['Apple', 'Google', 'Meta', 'Amazon', 'Meta', 'Microsoft']
brands.remove('Google')
print(brands)
# Out:
# ['Apple', 'Meta', 'Amazon', 'Meta', 'Microsoft']

# %%
brands = ['Apple', 'Google', 'Meta', 'Amazon', 'Meta', 'Microsoft']
del brands
print(brands)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_908/3672789162.py in <cell line: 0>()
#       1 brands = ['Apple', 'Google', 'Meta', 'Amazon', 'Meta', 'Microsoft']
#       2 del brands
# ----> 3 print(brands)
#
# NameError: name 'brands' is not defined

# %% [markdown]
# ## Problem. 淘汰賽與名單清理
# 現有一個名為 `players` 的玩家名單：`['小明', '小華', '小強', '小美', '小強', '大壯']`。
# 1.  領獎退出： 使用 `pop()` 移除串列中的最後一個元素（大壯），並將其存入變數 `winner`，隨後印出「中獎的是：大壯」。
# 2.  指名淘汰： 使用 `remove()` 刪除名單中第一個出現的 `'小強'`。
# 3.  整排刪除： 使用 `del` 語法刪除索引 `0` 到 `2`（不包含 2）的玩家。
# 4.  剩餘名單： 印出最後剩下的 `players` 串列。
#
# 輸出內容：
# ```
# 中獎的是：大壯
# 剩餘的玩家：['小美', '小強']
# ```
# <!--
# ```python=
# players = ['小明', '小華', '小強', '小美', '小強', '大壯']
# winner = players.pop()
# print(f"中獎的是：{winner}")
# players.remove('小強')
# del players[0:2]
# print(f"剩餘的玩家：{players}")
# ```
# -->

# %% [markdown]
# ## 相加、倍增與空值判斷

# %%
# 1. 相加：合併兩個名單
group_a = ['Apple', 'Banana']
group_b = ['Orange', 'Grape']
all_fruits = group_a + group_b
print(f"合併後的名單: {all_fruits}")
# Out:
# 合併後的名單: ['Apple', 'Banana', 'Orange', 'Grape']

# %%
# 2. 乘以數字：快速重複元素
star = ['★']
rank = star * 5
print(f"五星好評: {rank}")
# Out:
# 五星好評: ['★', '★', '★', '★', '★']

# %%
# 3. 空值判斷：檢查購物車
basket = []
# if basket:
#   print("有內容")
# else:
#   print("無內容")

if not basket:
    print("購物車是空的，快去買東西吧！")
# Out:
# 購物車是空的，快去買東西吧！

# %% [markdown]
# ### Problem. 資源大合併與空箱檢查
# 請依據以下要求完成操作：
# 1.  合併箱子： 建立兩個串列，`box_1` 內容為 `['金牌']`，`box_2` 內容為 `['銀牌', '銅牌']`。將兩者相加合併後存入變數 `total_box`。
# 2.  複製物資： 建立一個名為 `water` 的串列，內容為 `['水']`。使用乘以數字的方式，將其重複 `3` 次後存入變數 `supply`。
# 3.  檢查倉庫： 建立一個名為 `warehouse` 的空串列 `[]`。使用 `if not` 語法判斷如果串列是空的，請印出「倉庫目前沒有存貨」。
#
# 輸出內容：
# ```
# 合併後的箱子：['金牌', '銀牌', '銅牌']
# 補給品：['水', '水', '水']
# 倉庫目前沒有存貨
# ```
# <!--
# ```python=
# box_1 = ['金牌']
# box_2 = ['銀牌', '銅牌']
# total_box = box_1 + box_2
# print(f"合併後的箱子：{total_box}")
#
# water = ['水']
# supply = water * 3
# print(f"補給品：{supply}")
#
# warehouse = []
# if not warehouse:
#     print("倉庫目前沒有存貨")
# ```
# -->

# %% [markdown]
# ## 串列的搜尋與統計
#
# 當串列資料變多時，我們需要快速找出某個東西的位置，或是算算看它出現了幾次。
# -   `index(內容)`：告訴你該元素第一次出現的索引（位置）。
# -   `count(內容)`：統計該元素在串列中總共出現了幾次。

# %%
# 初始資料：一連串的投票紀錄
votes = ['Apple', 'Banana', 'Apple', 'Cherry', 'Apple', 'Banana']

# 1. index()：找出 'Banana' 第一次出現在哪裡
first_banana = votes.index('Banana')
print(f"第一根香蕉在索引：{first_banana}") # 輸出: 1

# 2. count()：統計 'Apple' 總共得到幾票
apple_total = votes.count('Apple')
print(f"蘋果總票數：{apple_total}") # 輸出: 3
# Out:
# 第一根香蕉在索引：1
# 蘋果總票數：3

# %% [markdown]
# ## Problem. 超市購物清單搜尋
# -   請建立一個名為 `cart` 的串列，內容依序存入：`'牛奶', '雞蛋', '蘋果', '麵包', '蘋果', '牛奶', '蘋果'`。
# -   使用 `index()` 找出 '麵包' 在清單中的索引位置，並將結果印出。
# -   使用 `count()` 計算 '蘋果' 在購物車中總共出現了幾次，並將結果印出。
#
# 輸出內容：
# ```
# 麵包的索引位置是：3
# 蘋果的總數量是：3
# ```
# <!--
# ```python=
# cart = ['牛奶', '雞蛋', '蘋果', '麵包', '蘋果', '牛奶', '蘋果']
# print(f"麵包的索引位置是：{cart.index('麵包')}")
# print(f"蘋果的總數量是：{cart.count('蘋果')}")
# ```
# -->

# %% [markdown]
# ## 串列排序與反轉
# -   `reverse()`：「原地反轉」。單純把順序倒過來，不看大小。
# -   `sort()`：「原地排序」。會直接打掉原本的順序，重新排列。
#     -   `reverse=True`：可以讓排序變成從大到小（降序）。
# -   `sorted()`：「產生副本」。原本的名單不動，另外給你一份排好的新名單。

# %%
# 1. reverse() 與 sort()：會改變原本的串列
scores = [70, 90, 80]
scores.reverse()
print(f"反轉後：{scores}") # [80, 90, 70]

scores.sort()
print(f"升序排序：{scores}") # [70, 80, 90]

# 2. sorted()：原本的串列保持不變
nums = [5, 2, 8]
new_nums = sorted(nums)
print(f"原串列不動：{nums}") # [5, 2, 8]
print(f"新生成的串列：{new_nums}") # [2, 5, 8]
# Out:
# 反轉後：[80, 90, 70]
# 升序排序：[70, 80, 90]
# 原串列不動：[5, 2, 8]
# 新生成的串列：[2, 5, 8]

# %% [markdown]
# ## Problem. 比賽得分管理
# -   建立成績： 請建立一個名為 `scores` 的串列，內容包含五位選手的分數：`[75, 92, 80, 65, 88]`。
# -   順序倒置： 使用 `reverse()` 將原本的分數順序直接反轉（不是排序，只是頭尾對調），並印出反轉後的 `scores`。
# -   由大到小排序： 使用 `sort()` 搭配 `reverse=True` 參數，將 `scores` 依照分數高低進行降序排序，最後印出結果。
#
# 輸出內容：
# ```
# 反轉後的成績：[88, 65, 80, 92, 75]
# 由大到小的成績：[92, 88, 80, 75, 65]
# ```
# <!--
# ```python=
# scores = [75, 92, 80, 65, 88]
# scores.reverse()
# print(f"反轉後的成績：{scores}")
#
# scores.sort(reverse=True)
# print(f"由大到小的成績：{scores}")
# ```
# -->

# %% [markdown]
# ## Problem. 原始名單保衛
# -   建立原始名單： 建立一個名為 `names` 的串列，內容為：`['Charlie', 'Alice', 'Bob']`。
# -   生成排序副本： 使用 `sorted()` 函式對 `names` 進行排序，並將排序後的新結果存入一個新變數 `sorted_names`。
# -   驗證差異： \* 印出原本的 `names` 串列，確認它維持原樣（未被排序）。
#     -   印出新變數 `sorted_names`，確認它是排好順序的（字母 A-Z）。
#
# 輸出內容：
# ```
# 原始名單保持不變：['Charlie', 'Alice', 'Bob']
# 新的排序名單：['Alice', 'Bob', 'Charlie']
# ```
# <!--
# ```python=
# names = ['Charlie', 'Alice', 'Bob']
# sorted_names = sorted(names)
# print(f"原始名單保持不變：{names}")
# print(f"新的排序名單：{sorted_names}")
# ```
# -->
