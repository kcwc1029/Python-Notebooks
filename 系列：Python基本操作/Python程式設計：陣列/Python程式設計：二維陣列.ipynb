# %% [markdown]
# 二維陣列可以想像成一個二維空間，就像一個表格或一張棋盤。它是由多個「串列」所組成的「串列」。也就是說，它的每個元素本身又是一個串列。
#
# ![upgit_20260421_1776782936.png](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260421_1776782936.png)

# %% [markdown]
# ### 範例：成績系統
# 用一個陣列sc表示每個學生的\[姓名、國文、英文、數學、總分\]
#
# | 姓名 | 國文 | 英文 | 數學 | 總分 |
# | --- | --- | --- | --- | --- |
# | 建富1號 | 80  | 95  | 88  | 263 |
# | 建富2號 | 98  | 97  | 96  | 291 |
# | 建富3號 | 91  | 93  | 95  | 279 |
# | 建富4號 | 92  | 94  | 90  | 276 |
# | 建富5號 | 92  | 97  | 80  | 269 |

# %%
# 建立學生資料陣列：姓名、國文、英文、數學、總分（初始為 0）
sc = [
    ["建富1號", 80, 95, 88, 0],
    ["建富2號", 98, 97, 96, 0],
    ["建富3號", 91, 93, 95, 0],
    ["建富4號", 92, 94, 90, 0],
    ["建富5號", 92, 97, 80, 0]
]

# 這邊我要去將每個學生的總分算出來
# 我們可以先以建富1號做實驗

# print(sc[0][1])
# print(sc[0][2])
# print(sc[0][3])
# print(sc[0][1:4])
# print(sum(sc[0][1:4]))
# sc[0][4] = sum(sc[0][1:4])
# print(sc[0][4])

# 重複，使用迴圈
# sc[0][4] = sum(sc[0][1:4])
# sc[1][4] = sum(sc[1][1:4])
# sc[2][4] = sum(sc[2][1:4])
# sc[3][4] = sum(sc[3][1:4])
# sc[4][4] = sum(sc[4][1:4])

# %% [markdown]
# ### Problem. 座標定位——水果庫存查詢
# 請建立一個名為 `inventory` 的二維陣列，代表超市的水果庫存表格。每一列包含：`[水果名稱, 庫存數量, 單價]`。 初始資料如下：
# -   `['蘋果', 50, 20]`
# -   `['香蕉', 120, 5]`
# -   `['葡萄', 80, 45]`
#
# 請執行以下操作：
# 1.  取出並印出「香蕉」的庫存數量（利用索引定位）。
# 2.  取出並印出「葡萄」的單價。
# 輸出內容：
# ```
# 香蕉的庫存數量是：120
# 葡萄的單價是：45
# ```
# <!--
# ```python=
# inventory = [
#     ['蘋果', 50, 20],
#     ['香蕉', 120, 5],
#     ['葡萄', 80, 45]
# ]
# print(f"香蕉的庫存數量是：{inventory[1][1]}")
# print(f"葡萄的單價是：{inventory[2][2]}")
# ```
# -->

# %% [markdown]
# ### Problem. 資料更新——成績修正
# 現有一份簡化版的學生成績單 `students`，包含：`[姓名, 國文分數, 數學分數]`。 名單為：`[['小明', 85, 60], ['小華', 70, 95]]`。
# 1.  老師發現「小明」的數學分數打錯了，請將小明的數學分數（索引為 `[0][2]` 的位置）從 `60` 修改為 `75`。
# 2.  印出修改後的整個 `students` 陣列。
#
# 輸出內容：
# ```
# 修正後的名單：[['小明', 85, 75], ['小華', 70, 95]]
# ```
#
# <!--
# ```python=
# students = [['小明', 85, 60], ['小華', 70, 95]]
# students[0][2] = 75
# print(f"修正後的名單：{students}")
# ```
# -->

# %% [markdown]
# ### Problem. 全班總分掃描
# 請建立一個包含四位學生資料的二維陣列 `class_data`：
# -   `["A", 60, 70, 80, 0]`
# -   `["B", 90, 90, 90, 0]`
# -   `["C", 50, 60, 50, 0]`
# -   `["D", 80, 75, 70, 0]`
#
# 請使用 `for` 迴圈遍歷（走訪）整個 `class_data`。在迴圈中，利用 `sum()` 搭配切片，自動計算每位學生的總分（索引 1 到 3 的總和），並填入索引 `4` 的位置。最後印出完整的陣列。
#
# 輸出內容：
# ```
# 全班總分計算完成：
# [['A', 60, 70, 80, 210], ['B', 90, 90, 90, 270], ['C', 50, 60, 50, 160], ['D', 80, 75, 70, 225]]
# ```
# <!--
# ```python=
# class_data = [
#     ["A", 60, 70, 80, 0],
#     ["B", 90, 90, 90, 0],
#     ["C", 50, 60, 50, 0],
#     ["D", 80, 75, 70, 0]
# ]
# for student in class_data:
#     student[4] = sum(student[1:4])
# print(f"全班總分計算完成：{class_data}")
# ```
# -->

# %% [markdown]
# ### Problem. 新增學生與資料統計
# 延續上一題的 class_data 陣列，請使用 append() 加入一位新學生 "E" 的資料：["E", 100, 100, 100, 0]。
# 單獨為這位新同學（最後一個元素）計算總分並填入。
# 使用 len() 函式印出目前班上總共有幾位學生。
# 輸出內容：
# ```
# 新增學生後人數：5
# 新學生的完整資料：['E', 100, 100, 100, 300]
# ```
# <!--
# ```python=
# new_student = ["E", 100, 100, 100, 0]
# class_data.append(new_student)
# class_data[-1][4] = sum(class_data[-1][1:4])
#
# print(f"新增學生後人數：{len(class_data)}")
# print(f"新學生的完整資料：{class_data[-1]}")
# ```
# -->
