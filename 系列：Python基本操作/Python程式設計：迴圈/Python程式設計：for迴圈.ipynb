# %% [markdown]
# for 迴圈用於遍歷任何可迭代物件中的元素。在每次迴圈迭代中，它會將物件中的一個元素指派給一個變數，然後執行迴圈內的程式碼。
# ![upgit_20260420_1776667664.png|329x184](https://raw.githubusercontent.com/kcwc1029/obsidian-upgit-image/main/2026/04/upgit_20260420_1776667664.png)

# %%
for i in range(5):
	print("哈哈")
# Out:
# 哈哈
# 哈哈
# 哈哈
# 哈哈
# 哈哈

# %%
for i in range(5):
	print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### range()：產生一個整數序列
# range() 函式是一種內建的可迭代物件，主要用於產生一個整數序列，通常用於 for 迴圈中以控制迴圈執行的次數。
# ```py
# range(start, stop, step)
# # 產生從 start 開始，
# # 到 stop-1 結束，
# # 每次以 step 為步長的整數序列。step 可以是正數（遞增）或負數（遞減）。
# ```

# %%
for i in range(5):
    print(i)

# %%
for i in range(1, 5):
    print(i)

# %%
for i in range(1, 10, 2):
    print(i)

# %%
for i in range(10, 0, -2):
    print(i)

# %%
### 倒數計時器 (使用 range 函數)
# range(5, 0, -1) 的意思是：從 5 開始，跑到 0 為止(不包含0)，每次遞減 1
print("跨年倒數開始：")

for i in range(5, 0, -1):
    print(i)
    
print("新年快樂！")

# %%
### 點名系統 (走訪清單 / List Iteration)
# 這是 for 迴圈最常見的用法：把一個列表（List）裡面的東西，依序拿出來處理。
students = ["小明", "小華", "小美", "阿強"]

print("開始點名：")
# "student" 只是一個暫時的代名詞，代表每次拿出來的那個人
for student in students:
    print(f"{student} 到了！")
    
print("點名結束。")

# %%
### 撲滿存錢筒 (累加器 / Accumulation)
# 這是初學者一定要學會的經典技巧：在迴圈外面準備一個「空箱子（變數 = 0）」，然後用迴圈把東西一直加進去。
# 假設這是一週每天存下的零用錢
savings = [50, 100, 30, 20, 150, 0, 200]

# 準備一個變數當作撲滿，初始值為 0
total_money = 0

for money in savings:
    # 每次迴圈執行時，把當天的錢加到撲滿裡
    total_money = total_money + money  # 也可以簡寫成 total_money += money
    print(f"今天存了 {money} 元，撲滿裡有 {total_money} 元了。")

print(f"這禮拜總共存了：{total_money} 元！")

# %%
### 字母過濾器 (結合 for 與 if)
# 迴圈裡面當然也可以放我們上次學過的判斷式，用來過濾或尋找特定的資料。
word = "Apple"
vowels = ["A", "a", "E", "e", "I", "i", "O", "o", "U", "u"]

print(f"分析單字：{word}")

for letter in word:
    if letter in vowels:
        print(f"[{letter}] 是母音")
    else:
        print(f"[{letter}] 是子音")

# %% [markdown]
# ## 雙重for迴圈

# %%
### 範例：九九乘法表
for i in range(1, 10):
    for j in range(1, 10):
        result = i * j
        print(f"{i}*{j}={result}", end='\t') # 使用 `end='\t'` 讓輸出在同一行，並以 tab 分隔
    print() # 內層迴圈結束後，換行

# %%
### 蝶帶兩個陣列
colors = ["Red", "Green", "Blue"]
shapes = ["Circle", "Square", "Line"]

for color in colors:
    for shape in shapes:
        print(f"顏色: {color}, 形狀: {shape}")

# %% [markdown]
# ## break：強制離開 for 迴圈

# %%
scores = [85, 92, 78, 95, 88]
for score in scores:
    if score > 90:
        print(f"找到第一個超過 90 分的成績：{score}")
        break # 找到後立即終止迴圈

# %% [markdown]
# ## continue：迴圈暫停但不終止

# %%
### 範例：只列印偶數
for i in range(10):
    if i % 2 != 0:
        continue # 如果是奇數，跳過本次迴圈
    print(i)

# %% [markdown]
# ## 練習
# * [Zerojudge連結](https://drive.google.com/file/d/1aoTO5v-eWeM0r1qkIz86sFmPsaiOuCyu/view?usp=sharing)

# %% [markdown]
# ### Problem. 採買清單小幫手 (認識 for 迴圈)
# * 你去超市買東西，口袋裡有一張採買清單，你需要看著清單，把東西一樣一樣拿出來結帳。
# * 請先建立一個購物清單，裡面包含三個文字資料：蘋果、牛奶、麵包，並將這個清單存入變數 shopping_list。
# * 執行邏輯：使用 for 迴圈，將 shopping_list 裡面的物品逐一取出，每次取出的物品請存入變數 item。
# * 輸出規範：在迴圈內，印出：準備結帳： 加上目前的物品名稱（例如：準備結帳： 蘋果）。
# <!--
# ```python=
# shopping_list = ['蘋果', '牛奶', '麵包']
# for item in shopping_list:
#     print(f"準備結帳： {item}")
# ```
# -->

# %% [markdown]
# ### Problem. 每日復健運動計數
# * 生活情境：醫生囑咐每天要連續做 5 次深蹲復健，你想寫個小程式幫自己數數。
# * 題目描述：請使用 range() 函式來產生從 1 到 5 的數字序列。
# * 執行邏輯：寫一個 for 迴圈，使用 range(1, 6) 讓迴圈執行 5 次，每次的數字存入變數 count。
# * 輸出規範：在迴圈內，印出：完成第 幾 次深蹲（請將 幾 替換為 count 的數字）。
# <!--
# ```python=
# for count in range(1, 6):
#     print(f"完成第 {count} 次深蹲")
# ```
# -->

# %% [markdown]
# ### Problem. 微波爐倒數計時
# * 生活情境：微波爐加熱食物時，螢幕上的秒數會從大到小慢慢倒數，最後發出逼逼聲。
# * 題目描述：請使用 range() 函式，設定起點為 5，終點為 0，步長為 -1，來產生 5 到 1 的倒數數字。
# * 執行邏輯：寫一個 for 迴圈，將倒數的數字存入變數 second。
# * 輸出規範：在迴圈內，印出：剩下 幾 秒（將 幾 替換為 second 的數字）。當迴圈整個結束後（在迴圈之外），印出：微波完成！。
# <!--
# ```python=
# for second in range(5, 0, -1):
#     print(f"剩下 {second} 秒")
#
# print("微波完成！")
# ```
# -->

# %% [markdown]
# ### Problem. 每日出門穿搭指南 (雙重 for 迴圈)
# * 生活情境：衣櫃裡有兩件上衣和兩件褲子，你想列出所有可能的搭配方式，看看明天要穿哪一套。
# * 題目描述：建立一個上衣清單存入變數 tops，內容為：紅襯衫、白T恤。接著建立一個褲子清單存入變數 bottoms，內容為：黑長褲、牛仔褲。
# * 執行邏輯：先寫一個外層 for 迴圈，把 tops 的衣服逐一拿出存入變數 top。在裡面再寫一個內層 for 迴圈，把 bottoms 的褲子逐一拿出存入變數 bottom。
# * 輸出規範：在內層迴圈中，印出搭配結果：上衣穿 [top] ，褲子穿 [bottom]（請將括號處替換為實際變數內容）。
# <!--
# ```python=
# tops = ['紅襯衫', '白T恤']
# bottoms = ['黑長褲', '牛仔褲']
#
# for top in tops:
#     for bottom in bottoms:
#         print(f"上衣穿 {top} ，褲子穿 {bottom}")
# ```
# -->

# %% [markdown]
# ### Problem. 社區農園種菜排排站
# * 生活情境：你在社區認養了一塊小農地，預計要種植 3 排高麗菜，每排種 4 顆。你想先在紙上畫出位置圖。
# * 題目描述：我們需要兩層迴圈來模擬排數與每排的顆數。
# * 執行邏輯：外層 for 迴圈使用 range(1, 4)，變數命名為 row，代表第 1 到 3 排。內層 for 迴圈使用 range(1, 5)，變數命名為 col，代表每排的第 1 到 4 顆。
# * 輸出規範：在內層迴圈中，印出文字：菜，並在 print 加上 end=' ' 讓字不要換行。在內層迴圈結束後（回到外層迴圈的對齊位置），使用一個空的 print() 來進行換行。
# <!--
# ```python=
# for row in range(1, 4):
#     for col in range(1, 5):
#         print("菜", end=' ')
#     print()
# ```
# -->

# %% [markdown]
# ### Problem. 找出不新鮮的雞蛋
# * 生活情境：你買了一盒雞蛋，正在一顆一顆檢查。只要發現有一顆是破掉的，你就會立刻停下來拿去退貨，不繼續檢查後面的了。
# * 題目描述：建立一個雞蛋狀態清單，存入變數 eggs，內容依序為：正常、正常、破掉、正常。
# * 執行邏輯：使用 for 迴圈將 eggs 裡的雞蛋狀態逐一取出，存入變數 status。檢查 status 的文字內容。
# * 輸出規範：如果 status 是 正常，印出：這顆雞蛋沒問題。如果 status 是 破掉，印出：發現破掉的雞蛋，停止檢查去退貨！，然後立刻使用 break 中斷迴圈。
# <!--
# ```python=
# eggs = ['正常', '正常', '破掉', '正常']
#
# for status in eggs:
#     if status == '破掉':
#         print("發現破掉的雞蛋，停止檢查去退貨！")
#         break
#     else:
#         print("這顆雞蛋沒問題")
# ```
# -->

# %% [markdown]
# ### Problem. 醫院叫號跳過空號
# * 生活情境：診所的螢幕正在叫號，但護理師知道 4 號病人請假沒來，所以叫到 4 號時要直接跳過，繼續叫下一位。
# * 題目描述：使用 range(1, 6) 產生 1 到 5 的號碼。
# * 執行邏輯：寫一個 for 迴圈，將號碼存入變數 number。使用 if 判斷式檢查號碼是否等於 4。
# * 輸出規範：如果 number 是 4，使用 continue 直接跳過這回合，不執行後面的動作。如果不是 4，則印出：請 幾 號病患進診間（將 幾 替換為 number）。
# <!--
# ```python=
# for number in range(1, 6):
#     if number == 4:
#         continue
#     print(f"請 {number} 號病患進診間")
# ```
# -->

# %% [markdown]
# ### Problem 整理舊錢包的零錢
# * 生活情境：你翻出一個舊錢包，裡面有一些硬幣和垃圾。你要把硬幣拿出來算錢，遇到垃圾就丟掉（跳過），但如果突然翻到一張千元大鈔，你就太開心了，決定直接收工去吃大餐！
# * 題目描述：建立一個物品清單，存入變數 wallet，內容依序為：10、垃圾、50、1000、5。
# * 執行邏輯：使用 for 迴圈將 wallet 裡的物品逐一取出，存入變數 item。
# * 輸出規範：
#     * 如果 item 是文字 垃圾，使用 continue 跳過這回合。
#     * 如果 item 是數字 1000，印出：發現一千元！發財了，收工休息！，並使用 break 結束整個迴圈。
#     * 如果是其他數字，印出：撿到 多少 元（將 多少 替換為 item）。
# <!--
# ```python=
# wallet = [10, '垃圾', 50, 1000, 5]
#
# for item in wallet:
#     if item == '垃圾':
#         continue
#
#     if item == 1000:
#         print("發現一千元！發財了，收工休息！")
#         break
#
#     print(f"撿到 {item} 元")
# ```
# -->
