# %% [markdown]
# ### Problem. 基礎列表去重
# 寫一個程式，接收一個包含重複數字的列表，將其轉換為集合以移除重複元素，最後印出結果。
# * 輸入變數：input_list = `1, 2, 2, 3, 4, 4, 5`
# * 輸出變數：unique_set
#
# <!--
# ```cpp=
# input_list = [1, 2, 2, 3, 4, 4, 5]
# unique_set = set(input_list)
# print(unique_set)
# ```
# -->

# %% [markdown]
# ### Problem. 新增單一元素
# 建立一個包含字串的集合。使用集合的內建方法將一個新字串加入該集合，最後印出更新後的集合。
# * 輸入變數：student_set = {'Alice', 'Bob'}，要加入的元素為 'Charlie'
# * 輸出變數：無特別指定新變數，請直接更新並印出 student_set
# <!--
# ```cpp=
# student_set = {'Alice', 'Bob'}
# student_set.add('Charlie')
# print(student_set)
# ```
# -->

# %% [markdown]
# ### Problem. 安全地刪除元素
# 給定一個水果集合。請撰寫程式嘗試移除一個指定的目標元素。請使用 try 與 except 捕捉 KeyError 錯誤，若發生錯誤則印出「找不到該元素」。
# * 輸入變數：fruits = {'apple', 'banana', 'orange'}，target_item = 'grape'
# * 輸出變數：直接對 fruits 進行操作
# <!--
# ```cpp=
# fruits = {'apple', 'banana', 'orange'}
# target_item = 'grape'
# try:
#     fruits.remove(target_item)
# except KeyError:
#     print("找不到該元素")
# ```
# -->

# %% [markdown]
# ### Problem. 隨機移除並取得元素
# 給定一個顏色集合。請使用集合的方法隨機移除一個元素，將被移除的元素存入特定變數中，最後印出被移除的元素以及更新後的集合。
# * 輸入變數：colors = {'red', 'green', 'blue'}
# * 輸出變數：removed_color
#
# <!--
# ```cpp=
# colors = {'red', 'green', 'blue'}
# removed_color = colors.pop()
# print("被移除的顏色:", removed_color)
# print("剩下的顏色:", colors)
# ```
# -->

# %% [markdown]
# ### Problem. 合併列表至集合
# 給定一個基礎集合與一個包含新元素的列表。請使用集合的方法將列表中的所有元素合併到基礎集合中，最後印出更新後的集合。
# * 輸入變數：base_set = {1, 2, 3}，new_elements = [3, 4, 5]
# * 輸出變數：直接更新並印出 base_set
# <!--
# ```cpp=
# base_set = {1, 2, 3}
# new_elements = [3, 4, 5]
# base_set.update(new_elements)
# print(base_set)
# ```
# -->

# %% [markdown]
# ### Problem. 聯集運算（全部名單）
# 有兩個社團的學生名單集合。請找出所有至少參加一個社團的學生，將結果存入新變數，並印出結果。可以使用方法或運算符。
# * 輸入變數：guitar_club = {'John', 'Mary', 'Tom'}，dance_club = {'Mary', 'Kevin', 'Tom'}
# * 輸出變數：all_students
# <!--
# ```cpp=
# guitar_club = {'John', 'Mary', 'Tom'}
# dance_club = {'Mary', 'Kevin', 'Tom'}
# all_students = guitar_club.union(dance_club) # 或使用 guitar_club | dance_club
# print(all_students)
# ```
# -->

# %% [markdown]
# ### Problem. 交集運算（共同名單）
# 承接上一題的社團名單，請找出同時參加吉他社與熱舞社的學生，將結果存入新變數，並印出結果。
# * 輸入變數：guitar_club = {'John', 'Mary', 'Tom'}，dance_club = {'Mary', 'Kevin', 'Tom'}
# * 輸出變數：both_clubs
# <!--
# ```cpp=
# guitar_club = {'John', 'Mary', 'Tom'}
# dance_club = {'Mary', 'Kevin', 'Tom'}
# both_clubs = guitar_club.intersection(dance_club) # 或使用 guitar_club & dance_club
# print(both_clubs)
# ```
# -->

# %%
### Problem. 差集運算（單一社團）
承接社團名單，請找出只有參加吉他社，但沒有參加熱舞社的學生，將結果存入新變數，並印出結果。
* 輸入變數：guitar_club = {'John', 'Mary', 'Tom'}，dance_club = {'Mary', 'Kevin', 'Tom'}
* 輸出變數：only_guitar
<!--  
```cpp=
guitar_club = {'John', 'Mary', 'Tom'}
dance_club = {'Mary', 'Kevin', 'Tom'}
only_guitar = guitar_club.difference(dance_club) # 或使用 guitar_club - dance_club
print(only_guitar)
```
-->

# %% [markdown]
# ### Problem. 差集運算（單一社團）
# 承接社團名單，請找出只有參加吉他社，但沒有參加熱舞社的學生，將結果存入新變數，並印出結果。
# * 輸入變數：guitar_club = {'John', 'Mary', 'Tom'}，dance_club = {'Mary', 'Kevin', 'Tom'}
# * 輸出變數：only_guitar
# <!--
# ```cpp=
# guitar_club = {'John', 'Mary', 'Tom'}
# dance_club = {'Mary', 'Kevin', 'Tom'}
# only_guitar = guitar_club.difference(dance_club) # 或使用 guitar_club - dance_club
# print(only_guitar)
# ```
# -->

# %% [markdown]
# ### Problem. 字串字元去重
# 給定一個字串。請將該字串轉換為集合，藉此找出字串中所有出現過的不重複字元，將結果存入新變數並印出。
# * 輸入變數：text = "hello world"
# * 輸出變數：char_set
# <!--
# ```cpp=
# text = "hello world"
# char_set = set(text)
# print(char_set)
# ```
# -->

# %% [markdown]
# ### Problem. 空集合的建立與型態確認
# 請建立一個真正的空集合與一個空字典，分別存入對應的變數中，並使用 type() 函數印出這兩個變數的資料型態，驗證建立是否正確。
# * 輸入變數：無
# * 輸出變數：empty_set, empty_dict
# <!--
# ```cpp=
# empty_set = set()
# empty_dict = {}
# print("empty_set 型態:", type(empty_set))
# print("empty_dict 型態:", type(empty_dict))
# ```
# -->
