# %% [markdown]
# ## Problem. 基本輸入與 f-string 輸出
# 請設計一個程式，詢問使用者的名字與年紀，並使用 f-string 格式化輸出一句問候語。
#
# 變數名稱與輸入設定：
# * user_name：使用 input() 讀取姓名
# * user_age：使用 input() 讀取年紀
#
# 輸出要求：印出「您好，[user_name]！原來您已經 [user_age] 歲了。」
# <!--
# ```python
# user_name = input("請輸入您的姓名：")
# user_age = input("請輸入您的年紀：")
# print(f"您好，{user_name}！原來您已經 {user_age} 歲了。")
# ```
#  -->

# %% [markdown]
# ## Problem. format() 格式化輸出
# 請設計一個點餐程式，讀取餐點名稱與數量，並使用 format() 函數產生訂單明細。
#
# 變數名稱與輸入設定：
# * meal_name：使用 input() 讀取餐點名稱
# * quantity：使用 input() 讀取數量
#
# 輸出要求：印出「訂單確認：[meal_name] 共 [quantity] 份」
#
# <!--
# meal_name = input("請輸入餐點名稱：")
# quantity = input("請輸入數量：")
# print("訂單確認：{} 共 {} 份".format(meal_name, quantity))
#  -->

# %% [markdown]
# ## Problem. 型態轉換與數學計算
# 請讀取長方形的長與寬（皆為整數），計算出面積並印出。
#
# 變數名稱與輸入設定：
# * length_str：使用 input() 讀取長度
# * width_str：使用 input() 讀取寬度
# * area：將上述兩者轉為整數後相乘
#
# 輸出要求：印出 area 的數值。
# <!--
# length_str = input("請輸入長度：")
# width_str = input("請輸入寬度：")
# area = int(length_str) * int(width_str)
# print(area)
#  -->

# %% [markdown]
# ## Problem. 字串運算式轉換 eval()
# 請製作一個微型計算機，讓使用者直接輸入一段數學公式，程式將自動計算並輸出結果。
#
# 變數名稱與輸入設定：
# * math_formula：使用 input() 讀取包含加減乘除的字串公式（例如 10+5*2）
# * result：使用 eval() 計算 math_formula 的結果
#
# 輸出要求：使用 f-string 印出「公式計算結果為：[result]」
#
# <!--
# math_formula = input("請輸入數學公式：")
# result = eval(math_formula)
# print(f"公式計算結果為：{result}")
#  -->

# %% [markdown]
# ## Problem. 寫入檔案基本操作
# 請利用 Python 的檔案寫入功能，建立一個純文字檔案，並在裡面寫入一行指定的文字。
#
# 變數名稱與輸入設定：
# * file_name：設定為 "welcome.txt"
# * text_content：設定為 "歡迎來到 Python 的世界"
#
# 輸出要求：使用 with open() 語法，將 text_content 寫入 welcome.txt 檔案中。
#
# <!--
# file_name = "welcome.txt"
# text_content = "歡迎來到 Python 的世界"
# with open(file_name, mode="w", encoding="utf-8") as f:
#     print(text_content, file=f)
#  -->

# %% [markdown]
# ## Problem. 結合檔案與使用者輸入
# 請讓使用者輸入一句今天的座右銘，並將這句話儲存到檔案中。
#
# 變數名稱與輸入設定：
# * motto：使用 input() 讀取座右銘
# * file_name：設定為 "motto.txt"
#
# 輸出要求：開啟或建立 motto.txt，並將讀取到的 motto 寫入該檔案中。
#
# <!--
# motto = input("請輸入今天的座右銘：")
# file_name = "motto.txt"
# with open(file_name, mode="w", encoding="utf-8") as f:
#     print(motto, file=f)
#  -->
